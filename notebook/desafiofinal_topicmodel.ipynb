# %%
import pandas as pd
import spacy
import nltk
from nltk.stem import SnowballStemmer
import gensim
from gensim import corpora
import pyLDAvis.gensim
import pickle

# %%
from spacy.lang.es import Spanish
parser = Spanish()
nltk.download('stopwords')
es_stop = set(nltk.corpus.stopwords.words('spanish'))
stemmer = SnowballStemmer('spanish')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\abel1\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
es_stop |= {"https","hola","gracias"}

# %%
def tokenize(text):
    lda_tokens = []
    tokens = parser(text)
    for token in tokens:
        if token.orth_.isspace():
            continue
        elif token.like_url:
            lda_tokens.append('URL')
        elif token.orth_.startswith('@'):
            continue
            #lda_tokens.append('SCREEN_NAME')
        else:
            lda_tokens.append(token.lower_)
    return lda_tokens

# %%
def prepare_text_for_lda(text):
    tokens = tokenize(text)
    tokens = [token for token in tokens if len(token) > 4]
    tokens = [token for token in tokens if token not in es_stop]
    tokens = [stemmer.stem(token) for token in tokens]
    return tokens

# %%
path = r'C:\Users\abel1\Jupyter Notebooks\DH\DESAFIO 3\\'
claro_tweets = pd.read_excel(path + 'claro_prev.xlsx')
claro_tweets['company'] = 'claro'
movistar_tweets = pd.read_excel(path + 'movistar_prev.xlsx')
movistar_tweets['company'] = 'movistar'
personal_tweets = pd.read_excel(path + 'personal_prev.xlsx')
personal_tweets['company'] = 'personal'

# %%
#eliminamos todos los tweets de claro asociados a publicidad de eventos de gaming
claro_tweets=claro_tweets[claro_tweets.author_name != '9zTeam']
claro_tweets=claro_tweets[~claro_tweets.text.str.contains('9zteam',case=True)]

# %%
#claro_tweets[claro_tweets.text.str.contains('brasil',case=True)]

# %%
tweets_df = pd.concat([claro_tweets, movistar_tweets, personal_tweets]).reset_index()
tweets_df['tokens'] = tweets_df.apply(lambda x: prepare_text_for_lda(x.text), axis=1)

# %%
tweets_df.company.value_counts()
# Out:
# movistar    1075
# claro        984
# personal     906
# Name: company, dtype: int64

# %%
tweets_df['bigrams'] = tweets_df['tokens'].apply(lambda row: list(nltk.ngrams(row, 2)))

# %%
tweets_df['bigrams'] = tweets_df.apply(lambda x: ["_".join(tokens) for tokens in x['bigrams']], axis=1)

# %%
a = tweets_df[['company','bigrams']].set_index('company').explode('bigrams').reset_index().groupby(['company','bigrams']).size().reset_index()
a.sort_values(0, ascending=False)#.pivot_table(tweets_df,aggfunc='sum',index='company',,fill_value=True)
b = a.groupby('bigrams').sum().reset_index()
b['company'] = 'Total'
bigrams_counts_data = pd.concat([a,b]).reset_index(drop=True)
bigrams_counts_data.columns = ['company', 'ngram', 'value']
bigram_data  = bigrams_counts_data.pivot_table(index='ngram',columns='company', aggfunc='sum',fill_value=0)
bigram_data = bigram_data.droplevel(0,axis=1)
# Out:
# C:\Users\abel1\Anaconda3\envs\digital-house\lib\site-packages\ipykernel_launcher.py:5: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """

# %%
top_ngrams = bigrams_counts_data[bigrams_counts_data.company=='Total'].sort_values('value', ascending=False).head(20).ngram.unique()
top_ngrams_70 = bigrams_counts_data[bigrams_counts_data.company=='Total'].sort_values('value', ascending=False).head(1000).ngram.unique()

# %%
tweets_df.columns
# Out:
# Index(['index', 'text', 'author_name', 'created_at', 'id', 'text_clean',
#        'company', 'tokens', 'bigrams'],
#       dtype='object')

# %%
lookup =tweets_df[['id','company','bigrams']].set_index(['id','company']).explode('bigrams').reset_index().groupby(['id','company','bigrams']).size()
lookup = lookup.astype('bool').reset_index()
lookup = lookup[lookup['bigrams'].isin(top_ngrams_70)].set_index(['id','company','bigrams']).unstack(fill_value=False)
lookup = lookup.droplevel(0,axis=1).reset_index()

# %%
lookup = pd.merge(lookup,tweets_df[['id','created_at','tokens']])
lookup['text_clean'] = lookup.tokens.apply(" ".join)

# %%
lookup['Words'] = lookup.tokens.apply(len)

# %%
lookup['Words_clipped'] = lookup['Words']

# %%
lookup.company.value_counts()
# Out:
# movistar    719
# claro       646
# personal    552
# Name: company, dtype: int64

# %%
lookup.to_csv('lookup_tweets.csv')

# %%
lookup
# Out:
#                       id   company 20:30hs_celebr amig_esper amig_famili  \
# 0    1283458861769335040  personal          False      False       False
# 1    1283458902886174976  personal          False      False       False
# 2    1283459034268478976  personal          False      False       False
# 3    1283459335776023040  personal          False      False       False
# 4    1283472382691290880  personal          False      False       False
# ..                   ...       ...            ...        ...         ...
# 717  1286167261749957120     claro          False      False       False
# 718  1286169897270152960     claro          False      False       False
# 719  1286189353727939072     claro          False      False       False
# 720  1286195740130370048     claro          False      False       False
# 721  1286235512802607104     claro          False      False       False
#
#     amig_mañan atencion_client buen_tard celebr_amig compr_celul  ...  \
# 0        False           False      True       False       False  ...
# 1        False           False      True       False       False  ...
# 2        False           False      True       False       False  ...
# 3        False           False      True       False       False  ...
# 4        False           False      True       False       False  ...
# ..         ...             ...       ...         ...         ...  ...
# 717      False           False     False       False       False  ...
# 718      False           False     False       False       False  ...
# 719      False           False     False       False       False  ...
# 720      False           False     False       False       False  ...
# 721      False           False     False       False       False  ...
#
#     solucion_problem stream_manag suficient_phishing telecom_suficient  \
# 0              False        False              False             False
# 1              False        False              False             False
# 2              False        False              False             False
# 3              False        False              False             False
# 4              False        False              False             False
# ..               ...          ...                ...               ...
# 717            False         True              False             False
# 718            False         True              False             False
# 719            False        False              False             False
# 720            False         True              False             False
# 721            False        False              False             False
#
#     tir_felic victori_venc vuelv_tir vuelv_vuelv          created_at  \
# 0       False        False     False       False 2020-07-15 17:50:12
# 1       False        False     False       False 2020-07-15 17:50:22
# 2       False        False     False       False 2020-07-15 17:50:53
# 3       False        False     False       False 2020-07-15 17:52:05
# 4       False        False     False       False 2020-07-15 18:43:56
# ..        ...          ...       ...         ...                 ...
# 717     False        False     False       False 2020-07-23 05:12:25
# 718     False        False     False       False 2020-07-23 05:22:54
# 719     False        False     False       False 2020-07-23 06:40:12
# 720     False        False     False       False 2020-07-23 07:05:35
# 721     False        False     False       False 2020-07-23 09:43:38
#
#                                             text_clean
# 0    @sifueraunaflor @personalar buenas tardes grac...
# 1    @sifueraunaflor @personalar buenas tardes grac...
# 2    @sifueraunaflor @personalar buenas tardes grac...
# 3    @sifueraunaflor @personalar @defensoriacaba bu...
# 4    @personalar buenas tardes abone mi factura el ...
# ..                                                 ...
# 717  rt @filonewsok una entrevista entre @frankkast...
# 718  rt @filonewsok una entrevista entre @frankkast...
# 719  rt @9zteam locker room los esperamos a todos e...
# 720  rt @filonewsok una entrevista entre @frankkast...
# 721  rt @9zteam nuestro queridisimo @frankkasterx d...
#
# [722 rows x 74 columns]

# %%
top_bigrams_counts_data = bigrams_counts_data[bigrams_counts_data.ngram.isin(top_ngrams)].pivot_table(index='company',columns='ngram',fill_value=0).stack().reset_index()

# %%
bigram_data  = top_bigrams_counts_data.pivot_table(index='ngram',columns='company', aggfunc='sum',fill_value=0)
bigram_data = bigram_data.droplevel(0,axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-58-57acc89060b7> in <module>
# ----> 1 bigram_data  = top_bigrams_counts_data.pivot_table(index='ngram',columns='company', aggfunc='sum',fill_value=0)
#       2 bigram_data = bigram_data.droplevel(0,axis=1)
#
# NameError: name 'top_bigrams_counts_data' is not defined

# %%
bigram_data
# Out:
# company                Total  claro  movistar  personal
# ngram
# +543517247001_lueg       984    984         0         0
# ......_.....            1075      0      1075         0
# ......_sig               906      0         0       906
# ....._nadi               906      0         0       906
# ....._sig                906      0         0       906
# ...                      ...    ...       ...       ...
# yyyyyyyyyy_......        906      0         0       906
# zap_sumat                984    984         0         0
# zon_madr                 984    984         0         0
# zulem_marit              906      0         0       906
# ⁦@personalar⁩_telecom    906      0         0       906
#
# [11851 rows x 4 columns]

# %%
top_bigrams_counts_data.to_csv('bigrams_counts_data.csv', index=False)
bigram_data.reset_index().to_csv('bigram_data.csv', index=False)

# %%
dictionary = corpora.Dictionary(tweets_df['bigrams'].values)
tweets_df['bow'] = tweets_df.apply(lambda x: dictionary.doc2bow(x.bigrams), axis=1)
corpus = tweets_df['bow'].values

# %%
NUM_TOPICS = 4
ldamodel = gensim.models.ldamodel.LdaModel(corpus, num_topics = NUM_TOPICS, id2word=dictionary, passes=15)

# %%
def apply_topics(grp):
    topics = ldamodel.get_document_topics(grp['bow'])
    for i in range(len(topics)):
        grp[f'topic_{i}'] = topics[i][1]
    return grp
tweets_df = tweets_df.apply(apply_topics,axis=1)

# %%
topics = ldamodel.print_topics(num_words=6)
for topic in topics:
    print(topic)
# Out:
# (0, '0.004*"buen_tard" + 0.004*"recomend_realiz" + 0.003*"realiz_denunci" + 0.003*"dqoz7jjtyn_salud" + 0.003*"denunci_ingres" + 0.003*"ingres_dqoz7jjtyn"')
# (1, '0.003*"esper_respuest" + 0.002*"cobr_factur" + 0.002*"sig_darm" + 0.001*"aument_mes" + 0.001*"piens_reembols" + 0.001*"reembols_diner"')
# (2, '0.011*"movistargarc_movistargarc" + 0.006*"ransomwar_telecom" + 0.006*"cuid_ransomwar" + 0.006*"suficient_phishing" + 0.006*"telecom_suficient" + 0.004*"atencion_client"')
# (3, '0.004*"internet_hog" + 0.004*"contrat_internet" + 0.003*"hog_contrat" + 0.002*"consult_pued" + 0.002*"pued_mejor" + 0.002*"mejor_ofert"')

# %%
bigram_vectors=tweets_df[['bigrams','topic_0','topic_1','topic_2','topic_3']]

# %%
bigram_vectors.to_csv('bigram_vectors.csv', index=False)

# %%
lda_display = pyLDAvis.gensim.prepare(ldamodel, corpus, dictionary, sort_topics=False)
pyLDAvis.display(lda_display)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.rawgit.com/bmabey/pyLDAvis/files/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el4160018553370606809553226764"></div>
# <script type="text/javascript">
#
# var ldavis_el4160018553370606809553226764_data = {"mdsDat": {"x": [0.07643709888511695, -0.14526738596163308, 0.01658276464410178, 0.05224752243241436], "y": [0.10804444635563541, 0.012118814449228946, 0.006165831012532556, -0.12632909181739685], "topics": [1, 2, 3, 4], "cluster": [1, 1, 1, 1], "Freq": [24.6543025970459, 26.681285858154297, 23.579607009887695, 25.084802627563477]}, "tinfo": {"Term": ["movistargarc_movistargarc", "telecom_suficient", "ransomwar_telecom", "cuid_ransomwar", "suficient_phishing", "internet_hog", "contrat_internet", "recomend_realiz", "realiz_denunci", "denunci_ingres", "dqoz7jjtyn_salud", "ingres_dqoz7jjtyn", "prestacion_servici", "escrib_prestacion", "servici_contratacion", "atencion_client", "buen_tard", "contratacion_mism", "ambit_recomend", "mism_ambit", "hog_contrat", "esper_respuest", "consult_pued", "pued_mejor", "buen_escrib", "ofert_silenci", "mejor_ofert", "tard_escrib", "pesim_servici", "cobr_factur", "recomend_realiz", "realiz_denunci", "dqoz7jjtyn_salud", "ingres_dqoz7jjtyn", "denunci_ingres", "prestacion_servici", "servici_contratacion", "escrib_prestacion", "mism_ambit", "ambit_recomend", "contratacion_mism", "buen_escrib", "tard_escrib", "cambi_empres", "compr_telefon", "llam_personal", "clar_respet", "mism_mang", "mang_vuelaaaannnnnnnn", "quier_cambi", "men_senal", "vec_siempr", "respet_acord", "senal_vec", "acord_men", "hac_llam", "trat_compr", "celul_compr", "pandemi_cuarenten", "mes_reclam", "buen_tard", "pued_hac", "compr_celul", "dic_problem", "llam_vec", "necesit_ayud", "servici_internet", "dej_internet", "mand_mensaj", "intent_compr", "mensaj_priv", "cobr_factur", "deud_client", "reembols_diner", "delincuent_cobr", "piens_reembols", "duplic_piens", "factur_duplic", "pregunt_aument", "pod_hac", "aument_mes", "plaz_vist", "diner_ajen", "diner_plaz", "vist_hag", "hag_diner", "reclam_vi6yj3vil8", "client_nunc", "nadi_llam", "servici_pas", "quis_sab", "seguir_seguir", "ajen_pag", "porqueri_empres", "nuev_excus", "invent_nuev", "excus_enviarmel", "line_nunc", "nunc_client", "contest_priv", "pid_mism", "mism_verguenz", "esper_respuest", "hac_reclam", "sig_darm", "brind_servici", "hac_carg", "buen_noch", "lleg_factur", "cambi_compani", "servici_tecnic", "cobr_servici", "solucion_problem", "movistargarc_movistargarc", "suficient_phishing", "telecom_suficient", "cuid_ransomwar", "ransomwar_telecom", "pesim_servici", "queri_sab", "pued_contest", "amig_esper", "mensaj_text", "servici_quier", "denunci_defens", "quier_compr", "cambi_personal", "tecnic_activ", "esper_visit", "visit_tecnic", "activ_servici", "buen_ofert", "ofert_debit", "envi_esper", "monsters_necesit", "necesit_chromaticaballargentin", "quier_monsters", "envi_dat", "esper_cumpl", "descuent_ahor", "deberi_hab", "mism_pas", "podri_dec", "atencion_client", "defens_consumidor", "fibr_optic", "quier_servici", "line_nuev", "solucion_problem", "cort_line", "nadi_atiend", "falt_respet", "compr_equip", "line_personal", "servici_internet", "esper_respuest", "buen_tard", "contrat_internet", "internet_hog", "hog_contrat", "consult_pued", "pued_mejor", "mejor_ofert", "ofert_silenci", "line_telefon", "pued_trabaj", "hac_consult", "dat_movil", "esper_solucion", "acces_gratuit", "acord_empres", "empres_acces", "trav_acord", "client_estan", "pas_compani", "realiz_reclam", "mism_respuest", "llam_numer", "empres_mierd", "delincuent_abus", "abus_client", "cobr_vec", "movil_amig", "tarif_plen", "pandemi_dat", "moment_aument", "perdi_tard", "discut_envi", "tard_discut", "cre_perdi", "envi_mensaj", "mand_encuest", "pag_factur", "pued_respond", "nunc_lleg", "pod_escrib", "quier_cobr", "mensaj_priv", "pued_cre", "debit_automat", "estan_cobr"], "Freq": [48.0, 27.0, 27.0, 27.0, 27.0, 17.0, 17.0, 16.0, 15.0, 15.0, 15.0, 15.0, 15.0, 15.0, 15.0, 20.0, 20.0, 14.0, 14.0, 14.0, 13.0, 18.0, 11.0, 10.0, 9.0, 9.0, 9.0, 8.0, 7.0, 8.0, 16.28986930847168, 15.28361701965332, 15.283615112304688, 15.283615112304688, 15.283615112304688, 15.282556533813477, 14.9317 ...

# %%
lda_display = pyLDAvis.gensim.prepare(ldamodel, corpus, dictionary, sort_topics=False)
pyLDAvis.display(lda_display)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.rawgit.com/bmabey/pyLDAvis/files/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el4160018551783586009400909478"></div>
# <script type="text/javascript">
#
# var ldavis_el4160018551783586009400909478_data = {"mdsDat": {"x": [0.07643709888511695, -0.14526738596163308, 0.01658276464410178, 0.05224752243241436], "y": [0.10804444635563541, 0.012118814449228946, 0.006165831012532556, -0.12632909181739685], "topics": [1, 2, 3, 4], "cluster": [1, 1, 1, 1], "Freq": [24.65428924560547, 26.68129539489746, 23.57961082458496, 25.084808349609375]}, "tinfo": {"Term": ["movistargarc_movistargarc", "cuid_ransomwar", "telecom_suficient", "ransomwar_telecom", "suficient_phishing", "internet_hog", "contrat_internet", "recomend_realiz", "realiz_denunci", "dqoz7jjtyn_salud", "ingres_dqoz7jjtyn", "denunci_ingres", "prestacion_servici", "escrib_prestacion", "servici_contratacion", "atencion_client", "buen_tard", "ambit_recomend", "mism_ambit", "contratacion_mism", "hog_contrat", "esper_respuest", "consult_pued", "pued_mejor", "buen_escrib", "mejor_ofert", "ofert_silenci", "tard_escrib", "pesim_servici", "cobr_factur", "recomend_realiz", "dqoz7jjtyn_salud", "realiz_denunci", "ingres_dqoz7jjtyn", "denunci_ingres", "prestacion_servici", "servici_contratacion", "escrib_prestacion", "mism_ambit", "contratacion_mism", "ambit_recomend", "buen_escrib", "tard_escrib", "cambi_empres", "compr_telefon", "llam_personal", "clar_respet", "mism_mang", "mang_vuelaaaannnnnnnn", "quier_cambi", "senal_vec", "men_senal", "respet_acord", "vec_siempr", "acord_men", "hac_llam", "trat_compr", "celul_compr", "pandemi_cuarenten", "mes_reclam", "buen_tard", "pued_hac", "compr_celul", "dic_problem", "llam_vec", "necesit_ayud", "servici_internet", "dej_internet", "mand_mensaj", "intent_compr", "mensaj_priv", "cobr_factur", "deud_client", "reembols_diner", "piens_reembols", "factur_duplic", "duplic_piens", "delincuent_cobr", "pregunt_aument", "pod_hac", "aument_mes", "plaz_vist", "hag_diner", "diner_ajen", "diner_plaz", "vist_hag", "reclam_vi6yj3vil8", "client_nunc", "nadi_llam", "servici_pas", "quis_sab", "seguir_seguir", "ajen_pag", "porqueri_empres", "nuev_excus", "invent_nuev", "excus_enviarmel", "line_nunc", "nunc_client", "contest_priv", "pid_mism", "mism_verguenz", "esper_respuest", "hac_reclam", "sig_darm", "brind_servici", "hac_carg", "buen_noch", "lleg_factur", "cambi_compani", "servici_tecnic", "cobr_servici", "solucion_problem", "movistargarc_movistargarc", "suficient_phishing", "cuid_ransomwar", "ransomwar_telecom", "telecom_suficient", "pesim_servici", "queri_sab", "pued_contest", "amig_esper", "mensaj_text", "servici_quier", "denunci_defens", "quier_compr", "cambi_personal", "esper_visit", "tecnic_activ", "activ_servici", "visit_tecnic", "ofert_debit", "buen_ofert", "envi_esper", "necesit_chromaticaballargentin", "monsters_necesit", "quier_monsters", "envi_dat", "esper_cumpl", "descuent_ahor", "deberi_hab", "mism_pas", "podri_dec", "atencion_client", "defens_consumidor", "fibr_optic", "quier_servici", "line_nuev", "solucion_problem", "cort_line", "nadi_atiend", "falt_respet", "compr_equip", "line_personal", "servici_internet", "esper_respuest", "buen_tard", "contrat_internet", "internet_hog", "hog_contrat", "consult_pued", "pued_mejor", "mejor_ofert", "ofert_silenci", "line_telefon", "pued_trabaj", "hac_consult", "dat_movil", "esper_solucion", "acces_gratuit", "empres_acces", "trav_acord", "acord_empres", "client_estan", "pas_compani", "realiz_reclam", "mism_respuest", "llam_numer", "empres_mierd", "delincuent_abus", "abus_client", "cobr_vec", "tarif_plen", "pandemi_dat", "movil_amig", "moment_aument", "cre_perdi", "tard_discut", "perdi_tard", "envi_mensaj", "mand_encuest", "pag_factur", "pued_respond", "nunc_lleg", "pod_escrib", "quier_cobr", "mensaj_priv", "pued_cre", "debit_automat", "estan_cobr"], "Freq": [48.0, 27.0, 27.0, 27.0, 27.0, 17.0, 17.0, 16.0, 15.0, 15.0, 15.0, 15.0, 15.0, 15.0, 15.0, 20.0, 20.0, 14.0, 14.0, 14.0, 13.0, 18.0, 11.0, 10.0, 9.0, 9.0, 9.0, 8.0, 7.0, 8.0, 16.28985595703125, 15.283601760864258, 15.28360366821289, 15.283601760864258, 15.283601760864258, 15.282543182373047, 14.931699752807617, 14. ...

# %%
pyLDAvis.save_html(lda_display,'lda_report.html')

# %% [markdown]
# # EXPLORACION DE BIGRAMAS SOBRE TODO EL UNIVERSO

# %%
txt=[" ".join(tokens) for tokens in tweets_df['tokens'].values]

# %%
from string import punctuation
# remove punctuation and make lower case
txt = ''.join(c for c in txt if c not in punctuation).lower()

# %%
print(txt)
# Out:
# consult pued mejor ofert silenci negat abandon port numer estan notific y3iiqnqhlsacost despu veng pib arregl famos fibr optic pus l0sebrwoe7conmig esper actu vecinbuen respuest reclam pued sab cabl expliquconmig algun orientacion municbclar celebr cumplean 20aniversari podri favor respond tweet felicitacion muchbuen respuest reclam pued sab cabl expliquaverigu tuentiseman aprox problem recepcion llam entra direct casill pued comunic senal siempr equip modern prob reinici algun problem servicicort carg text tweets veloc speedtest lleg test mejor bastant complet carg relat rap algui ficfstcji7excelent servici clar senal mejor promocion mism atencion client resuelv rap vent telefon atencion personaliz acompan usuari recomaveriguconsult pued mejor ofert silencimati canal telefon fibr optic excelent servici client trabaj pag sufrconsult pued mejor ofert silenciconsult pued mejor ofert silenciacab dat pospag pued chat whatapp pued hac llam vide llam pandemi tenazzzzzzzzcomentari compart experient tendr present ahor consumidor pod compart informacion empres red socialseri buen ofert debit automatmariel seri buen ofert debit automatclarbuen invit observ consum clar fmmdxljmu7 seleccion opcion detall consum dud respect pod ayud intern lendsk3qffirm liberenwhatsappconmig jajajaj dej cabl camion encarg desastr peligrpid mism verguenz estan quer cobrconsult pued mejor ofert silenciconsult pued mejor ofert silencireclamdaniel perdon demor respond escribim necesit nuev pas numer trabajestefani hac revision coment necesit envi informacion envi dat personal tambi pod obten informacion ingres qogdvdgizf esper contactencantari gent restituyer servici hog mejor amig pod chusm medi servicinecesitari ayudsac actualiz cuatr mes desactualizrespondiposibl gent subnormal mand fot wasap agarr cualqui numer mand gent estup algun usted celul protej dwy3shijmspid mism verguenz3219937844internet juevmand llam dig ten atencion client twitt mweaghpttnfunc viaj amer mism habl dat telefon golazfactur servici mes vuelt cambi pensalmand servici client falt ortografi servici horrendpregunt exist servici client pretend manten tal desastr qued aquell client siempr razonpesim atencion coherent servici mierd prestvamon clardat precis solicit esper respuestchanc personalatent decision cans pag fortun personal atien llam cambibuen inici proces portabil pront line activmart lleg esperofrec barat delincuent planescribresult actualiz celul compr diciembr ahor desastr desastr moment fall expliquenm llev servici tecnic tir lun besiswdtvehw3qypes ten preci pesim senal aguant mejor nunc cobr funcion siempr igualpas senalgast datenvicancel ped mism carg volv carg esper llam nunc enter trat client apen line activ lincumpl diversion queri pedirt podri ayud felicot etiquet particip concurs agradeceri corazondejar avisartpes ten precicompart experientmaltrat haci usuaridat pid posibil pued indic aproxim dign contest much respuest esperfalt minut cumpl hor dat solicit nadi personal respond entrad personal balcarc salt hormuev centimetr portabil numerestaf nyveubmkqifavor adelantam fech instalacion porf laburaaacostar claroquetecobr carlosslim ednyhiahm5mentir papaaaaalgun tambi andand xnwlrgpe81esper respuestespermadr sujer met prov internet hogar clar celular saludclarit problem competent clar estan altur usted siempr debaj sacal angulvam clar caraj tiram mang consej clientestan serruch deciljjajajajajjajaajaajaajaajajajajajajajajaajajajajajajajajajajajajajajajajajajajajajaajaj mejorclarit problem competent clar estan altur ustedtranqui servici relaj march segun planregistr pod abon telefon clarservici internet porong cuarenten funcion aaaaaa aument problemquier denunci line celul perteneci empres secuestr clar consent autorizacion algun trat comunic clar telefon logr solicit situacion reviertnuev estaf atras line plen cuarenten falt trabaj pon estaf cobrandot tarif superior llam burl situacion moros unic respuesthablbolud estan peg terribl movist cualqui moment telecentr revolar ...

# %%
import nltk
import pandas as pd
from nltk.probability import FreqDist
from IPython.core.display import HTML

# We need the punkt library to tokenize the text
nltk.download("punkt")

# Tokenize the text into individual words
words = txt.split()

# Get the frequency distribution of the words into a data frame
fdist = FreqDist(words)
count_frame = pd.DataFrame(fdist, index =[0]).T
count_frame.columns = ['Count']
count_frame = count_frame.sort_values('Count', ascending=False)

# Display the dataframe as HTML (so it's not truncated)
display(HTML(count_frame.to_html()))
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\mportuese\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>servici</th>
#       <td>318</td>
#     </tr>
#     <tr>
#       <th>pued</th>
#       <td>207</td>
#     </tr>
#     <tr>
#       <th>internet</th>
#       <td>193</td>
#     </tr>
#     <tr>
#       <th>hac</th>
#       <td>187</td>
#     </tr>
#     <tr>
#       <th>llam</th>
#       <td>183</td>
#     </tr>
#     <tr>
#       <th>line</th>
#       <td>158</td>
#     </tr>
#     <tr>
#       <th>esper</th>
#       <td>139</td>
#     </tr>
#     <tr>
#       <th>mism</th>
#       <td>137</td>
#     </tr>
#     <tr>
#       <th>client</th>
#       <td>136</td>
#     </tr>
#     <tr>
#       <th>solucion</th>
#       <td>131</td>
#     </tr>
#     <tr>
#       <th>reclam</th>
#       <td>121</td>
#     </tr>
#     <tr>
#       <th>telefon</th>
#       <td>121</td>
#     </tr>
#     <tr>
#       <th>movistargarc</th>
#       <td>120</td>
#     </tr>
#     <tr>
#       <th>factur</th>
#       <td>117</td>
#     </tr>
#     <tr>
#       <th>mand</th>
#       <td>116</td>
#     </tr>
#     <tr>
#       <th>lleg</th>
#       <td>112</td>
#     </tr>
#     <tr>
#       <th>problem</th>
#       <td>111</td>
#     </tr>
#     <tr>
#       <th>pag</th>
#       <td>108</td>
#     </tr>
#     <tr>
#       <th>quier</th>
#       <td>107</td>
#     </tr>
#     <tr>
#       <th>respuest</th>
#       <td>106</td>
#     </tr>
#     <tr>
#       <th>nunc</th>
#       <td>97</td>
#     </tr>
#     <tr>
#       <th>numer</th>
#       <td>96</td>
#     </tr>
#     <tr>
#       <th>compr</th>
#       <td>93</td>
#     </tr>
#     <tr>
#       <th>empres</th>
#       <td>92</td>
#     </tr>
#     <tr>
#       <th>cobr</th>
#       <td>92</td>
#     </tr>
#     <tr>
#       <th>pas</th>
#       <td>92</td>
#     </tr>
#     <tr>
#       <th>mes</th>
#       <td>92</td>
#     </tr>
#     <tr>
#       <th>cambi</th>
#       <td>88</td>
#     </tr>
#     <tr>
#       <th>necesit</th>
#       <td>87</td>
#     </tr>
#     <tr>
#       <th>respond</th>
#       <td>85</td>
#     </tr>
#     <tr>
#       <th>movist</th>
#       <td>85</td>
#     </tr>
#     <tr>
#       <th>personal</th>
#       <td>84</td>
#     </tr>
#     <tr>
#       <th>ahor</th>
#       <td>83</td>
#     </tr>
#     <tr>
#       <th>clar</th>
#       <td>82</td>
#     </tr>
#     <tr>
#       <th>telecom</th>
#       <td>80</td>
#     </tr>
#     <tr>
#       <th>dic</th>
#       <td>76</td>
#     </tr>
#     <tr>
#       <th>ten</th>
#       <td>75</td>
#     </tr>
#     <tr>
#       <th>cort</th>
#       <td>75</td>
#     </tr>
#     <tr>
#       <th>estan</th>
#       <td>74</td>
#     </tr>
#     <tr>
#       <th>envi</th>
#       <td>73</td>
#     </tr>
#     <tr>
#       <th>pod</th>
#       <td>73</td>
#     </tr>
#     <tr>
#       <th>sab</th>
#       <td>73</td>
#     </tr>
#     <tr>
#       <th>ransomwar</th>
#       <td>71</td>
#     </tr>
#     <tr>
#       <th>suficient</th>
#       <td>70</td>
#     </tr>
#     <tr>
#       <th>dej</th>
#       <td>69</td>
#     </tr>
#     <tr>
#       <th>dat</th>
#       <td>67</td>
#     </tr>
#     <tr>
#       <th>nuev</th>
#       <td>67</td>
#     </tr>
#     <tr>
#       <th>mensaj</th>
#       <td>66</td>
#     </tr>
#     <tr>
#       <th>celul</th>
#       <td>63</td>
#     </tr>
#     <tr>
#       <th>nadi</th>
#       <td>63</td>
#     </tr>
#     <tr>
#       <th>atencion</th>
#       <td>62</td>
#     </tr>
#     <tr>
#       <th>contrat</th>
#       <td>62</td>
#     </tr>
#     <tr>
#       <th>atiend</th>
#       <td>59</td>
#     </tr>
#     <tr>
#       <th>mejor</th>
#       <td>59</td>
#     </tr>
#     <tr>
#       <th>ofrec</th>
#       <td>58</td>
#     </tr>
#     <tr>
#       <th>usted</th>
#       <td>57</td>
#     </tr>
#     <tr>
#       <th>portabil</th>
#       <td>56</td>
#     </tr>
#     <tr>
#       <th>priv</th>
#       <td>54</td>
#     </tr>
#     <tr>
#       <th>escrib</th>
#       <td>54</td>
#     </tr>
#     <tr>
#       <th>vec</th>
#       <td>53</td>
#     </tr>
#     <tr>
#       <th>seman</th>
#       <td>51</td>
#     </tr>
#     <tr>
#       <th>hog</th>
#       <td>50</td>
#     </tr>
#     <tr>
#       <th>tecnic</th>
#       <td>50</td>
#     </tr>
#     <tr>
#       <th>carg</th>
#       <td>48</td>
#     </tr>
#     <tr>
#       <th>siempr</th>
#       <td>48</td>
#     </tr>
#     <tr>
#       <th>habl</th>
#       <td>48</td>
#     </tr>
#     <tr>
#       <th>funcion</th>
#       <td>47</td>
#     </tr>
#     <tr>
#       <th>qued</th>
#       <td>47</td>
#     </tr>
#     <tr>
#       <th>sig</th>
#       <td>47</td>
#     </tr>
#     <tr>
#       <th>contest</th>
#       <td>46</td>
#     </tr>
#     <tr>
#       <th>denunci</th>
#       <td>44</td>
#     </tr>
#     <tr>
#       <th>tard</th>
#       <td>44</td>
#     </tr>
#     <tr>
#       <th>ningun</th>
#       <td>44</td>
#     </tr>
#     <tr>
#       <th>men</th>
#       <td>44</td>
#     </tr>
#     <tr>
#       <th>descuent</th>
#       <td>43</td>
#     </tr>
#     <tr>
#       <th>encim</th>
#       <td>42</td>
#     </tr>
#     <tr>
#       <th>algun</th>
#       <td>41</td>
#     </tr>
#     <tr>
#       <th>realiz</th>
#       <td>41</td>
#     </tr>
#     <tr>
#       <th>abon</th>
#       <td>41</td>
#     </tr>
#     <tr>
#       <th>despu</th>
#       <td>40</td>
#     </tr>
#     <tr>
#       <th>trabaj</th>
#       <td>40</td>
#     </tr>
#     <tr>
#       <th>mierd</th>
#       <td>40</td>
#     </tr>
#     <tr>
#       <th>segu</th>
#       <td>40</td>
#     </tr>
#     <tr>
#       <th>ayud</th>
#       <td>40</td>
#     </tr>
#     <tr>
#       <th>tiemp</th>
#       <td>39</td>
#     </tr>
#     <tr>
#       <th>senal</th>
#       <td>38</td>
#     </tr>
#     <tr>
#       <th>tambi</th>
#       <td>37</td>
#     </tr>
#     <tr>
#       <th>medi</th>
#       <td>37</td>
#     </tr>
#     <tr>
#       <th>aument</th>
#       <td>36</td>
#     </tr>
#     <tr>
#       <th>favor</th>
#       <td>35</td>
#     </tr>
#     <tr>
#       <th>fibr</th>
#       <td>35</td>
#     </tr>
#     <tr>
#       <th>lin</th>
#       <td>35</td>
#     </tr>
#     <tr>
#       <th>dijeron</th>
#       <td>34</td>
#     </tr>
#     <tr>
#       <th>buen</th>
#       <td>34</td>
#     </tr>
#     <tr>
#       <th>estaf</th>
#       <td>34</td>
#     </tr>
#     <tr>
#       <th>llev</th>
#       <td>33</td>
#     </tr>
#     <tr>
#       <th>falt</th>
#       <td>33</td>
#     </tr>
#     <tr>
#       <th>ped</th>
#       <td>33</td>
#     </tr>
#     <tr>
#       <th>gent</th>
#       <td>33</td>
#     </tr>
#     <tr>
#       <th>consult</th>
#       <td>33</td>
#     </tr>
#     <tr>
#       <th>equip</th>
#       <td>32</td>
#     </tr>
#     <tr>
#       <th>pes</th>
#       <td>32</td>
#     </tr>
#     <tr>
#       <th>comunic</th>
#       <td>32</td>
#     </tr>
#     <tr>
#       <th>cabl</th>
#       <td>31</td>
#     </tr>
#     <tr>
#       <th>debit</th>
#       <td>31</td>
#     </tr>
#     <tr>
#       <th>igual</th>
#       <td>30</td>
#     </tr>
#     <tr>
#       <th>deud</th>
#       <td>30</td>
#     </tr>
#     <tr>
#       <th>unic</th>
#       <td>30</td>
#     </tr>
#     <tr>
#       <th>ingres</th>
#       <td>30</td>
#     </tr>
#     <tr>
#       <th>argentin</th>
#       <td>29</td>
#     </tr>
#     <tr>
#       <th>podri</th>
#       <td>29</td>
#     </tr>
#     <tr>
#       <th>activ</th>
#       <td>29</td>
#     </tr>
#     <tr>
#       <th>arregl</th>
#       <td>28</td>
#     </tr>
#     <tr>
#       <th>compani</th>
#       <td>28</td>
#     </tr>
#     <tr>
#       <th>movil</th>
#       <td>28</td>
#     </tr>
#     <tr>
#       <th>cumpl</th>
#       <td>28</td>
#     </tr>
#     <tr>
#       <th>person</th>
#       <td>27</td>
#     </tr>
#     <tr>
#       <th>avis</th>
#       <td>27</td>
#     </tr>
#     <tr>
#       <th>recl</th>
#       <td>27</td>
#     </tr>
#     <tr>
#       <th>error</th>
#       <td>27</td>
#     </tr>
#     <tr>
#       <th>phishingcuid</th>
#       <td>26</td>
#     </tr>
#     <tr>
#       <th>instal</th>
#       <td>26</td>
#     </tr>
#     <tr>
#       <th>cuarenten</th>
#       <td>26</td>
#     </tr>
#     <tr>
#       <th>ofert</th>
#       <td>26</td>
#     </tr>
#     <tr>
#       <th>gestion</th>
#       <td>26</td>
#     </tr>
#     <tr>
#       <th>tarjet</th>
#       <td>26</td>
#     </tr>
#     <tr>
#       <th>preci</th>
#       <td>25</td>
#     </tr>
#     <tr>
#       <th>termin</th>
#       <td>25</td>
#     </tr>
#     <tr>
#       <th>algui</th>
#       <td>25</td>
#     </tr>
#     <tr>
#       <th>parec</th>
#       <td>25</td>
#     </tr>
#     <tr>
#       <th>jam</th>
#       <td>25</td>
#     </tr>
#     <tr>
#       <th>oper</th>
#       <td>24</td>
#     </tr>
#     <tr>
#       <th>teni</th>
#       <td>24</td>
#     </tr>
#     <tr>
#       <th>todavi</th>
#       <td>23</td>
#     </tr>
#     <tr>
#       <th>punt</th

# %%
# Get the frequency distribution of the remaining words

fdist = FreqDist(words)
count_frame = pd.DataFrame(fdist, index =[0]).T
count_frame.columns = ['Count']

# Plot the frequency of the top 60 words
counts = count_frame.sort_values('Count', ascending = False)
fig = plt.figure(figsize=(16, 9))
ax = fig.gca()    
counts['Count'][:60].plot(kind = 'bar', ax = ax, color='teal')
ax.set_title('Frecuencia de los tokens más habituales')
ax.set_ylabel('Frecuencia de tokens')
ax.set_xlabel('token')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-fb227b426737> in <module>
#       7 # Plot the frequency of the top 60 words
#       8 counts = count_frame.sort_values('Count', ascending = False)
# ----> 9 fig = plt.figure(figsize=(16, 9))
#      10 ax = fig.gca()
#      11 counts['Count'][:60].plot(kind = 'bar', ax = ax, color='teal')
#
# NameError: name 'plt' is not defined

# %%
#Generamos los bigramas

from nltk import ngrams
from nltk.probability import FreqDist
import matplotlib.pyplot as plt

# Get n-grams where n = 2
n = 2
nGramsInDoc = []
nGrams = ngrams(words, n)
for grams in nGrams:
    nWords = ' '.join(g for g in grams)
    nGramsInDoc.append(nWords)

# Count the frequency of each n-gram
fdist = FreqDist(nGramsInDoc)
count_frame = pd.DataFrame(fdist, index =[0]).T
count_frame.columns = ['Count']

# Plot the frequency of the top 60 bigrams
counts = count_frame.sort_values('Count', ascending = False)
fig = plt.figure(figsize=(16, 9))
ax = fig.gca()    
counts['Count'][:60].plot(kind = 'bar', ax = ax, color='teal')
ax.set_title('Frequency of the most common n-grams')
ax.set_ylabel('Frequency of n-gram')
ax.set_xlabel('n-gram')
plt.show()

# %%
count_frame.head()
